# %% [markdown]
# # ML Comptetition

# %% [markdown]
# Tried many different linear regression models:
#
#     • Linear Regression
#     • Lasso Regression
#     • Ridge Regression
#     👎 These did not perform well (high RSME, low R2)
#
#     • Decision Tree Regression
# Focused on:
#
#     • Random Forest
#     • KNeighbors
#
# Used:
#
#     • Different loops to check for parameters (k and depth) with best R2, RMSE and cross validation score
#     • Used different scalers (StandardScaler, MinMaxScaler, RobustScaler)
#     • GridSearchCV for parameter tuning
#
# Final and best Model:
#
#     • KNN with n = 27, N weighted by distance and StandardScaler
#
#     • Scores:
#       • RMSE = 0.641
#       • R2 = 0.656

# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %% [markdown]
# **Importing data**

# %%
cookies = pd.read_csv('../Data/cookies_lisa_test.csv')

# %%
cookies.head(3)
# Out:
#    Unnamed: 0  sugar to flour ratio  sugar index  bake temp  chill time  \
# 0           0                  0.25          9.5        300        15.0
# 1           1                  0.23          3.3        520        34.0
# 2           2                  0.18          1.9        360        33.0
#
#    calories  density    pH  grams baking soda  bake time  quality  \
# 0     136.0  0.99367  8.10               0.44       12.1        8
# 1     113.0  0.99429  8.16               0.48        8.4        7
# 2     106.0  0.98746  8.21               0.83       14.0        9
#
#    butter type  weight  chocolate  raisins  oats  nuts  peanut butter
# 0            1    15.2          0        1     0     0              0
# 1            1    12.4          0        1     0     0              0
# 2            1     9.4          1        0     0     1              0

# %%
cookies.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# ## KNN

# %%
range_list = [*range(1, 50, 1)]

scaler_list = [StandardScaler(), RobustScaler(), MinMaxScaler()]

X = cookies.drop(['quality'], axis=1)
y = cookies['quality']

X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=0)

#scaling the x values
for s in scaler_list:
    scaler = s
    print(s)
    scaler.fit(X_train)
    X_train_scale = scaler.transform(X_train)
    X_test_scale = scaler.transform(X_test)
    for k in range_list:
        Knn = KNeighborsRegressor(n_neighbors = k, weights = 'distance')
        Knn.fit(X_train_scale, y_train)
        y_pred = Knn.predict(X_test_scale)
        print('For K = ', k)
        print('R2:', round(r2_score(y_test, y_pred), 3))
        print('RMSE:', round(mean_squared_error(y_test, y_pred, squared=False), 3))
        print('Cross Validation Score: ', cross_val_score(Knn, X, y, cv=10).mean())
        print('')
# Out:
# StandardScaler()
# For K =  1
# R2: 0.583
# RMSE: 0.828
# Cross Validation Score:  0.40596102413212565
#
# For K =  2
# R2: 0.675
# RMSE: 0.731
# Cross Validation Score:  0.533928742310089
#
# For K =  3
# R2: 0.698
# RMSE: 0.705
# Cross Validation Score:  0.5818187552702068
#
# For K =  4
# R2: 0.714
# RMSE: 0.686
# Cross Validation Score:  0.6049906590329603
#
# For K =  5
# R2: 0.721
# RMSE: 0.677
# Cross Validation Score:  0.619048424784719
#
# For K =  6
# R2: 0.726
# RMSE: 0.671
# Cross Validation Score:  0.6302595800154712
#
# For K =  7
# R2: 0.728
# RMSE: 0.669
# Cross Validation Score:  0.6354495520975506
#
# For K =  8
# R2: 0.732
# RMSE: 0.664
# Cross Validation Score:  0.6405964944636715
#
# For K =  9
# R2: 0.737
# RMSE: 0.658
# Cross Validation Score:  0.6451485451265992
#
# For K =  10
# R2: 0.735
# RMSE: 0.66
# Cross Validation Score:  0.6498890097961112
#
# For K =  11
# R2: 0.738
# RMSE: 0.657
# Cross Validation Score:  0.6524647890920362
#
# For K =  12
# R2: 0.739
# RMSE: 0.655
# Cross Validation Score:  0.6552651118020297
#
# For K =  13
# R2: 0.739
# RMSE: 0.655
# Cross Validation Score:  0.6561851706262832
#
# For K =  14
# R2: 0.739
# RMSE: 0.654
# Cross Validation Score:  0.657754118257676
#
# For K =  15
# R2: 0.74
# RMSE: 0.654
# Cross Validation Score:  0.6598542460629663
#
# For K =  16
# R2: 0.74
# RMSE: 0.653
# Cross Validation Score:  0.6613778429649301
#
# For K =  17
# R2: 0.74
# RMSE: 0.654
# Cross Validation Score:  0.6626382272326852
#
# For K =  18
# R2: 0.741
# RMSE: 0.653
# Cross Validation Score:  0.6634755316447312
#
# For K =  19
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6636767997248071
#
# For K =  20
# R2: 0.741
# RMSE: 0.652
# Cross Validation Score:  0.6641432580115104
#
# For K =  21
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6649947453653379
#
# For K =  22
# R2: 0.742
# RMSE: 0.652
# Cross Validation Score:  0.6651769909383367
#
# For K =  23
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6658517805849665
#
# For K =  24
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.666489618453992
#
# For K =  25
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6668833090048651
#
# For K =  26
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6674637518798009
#
# For K =  27
# R2: 0.743
# RMSE: 0.651
# Cross Validation Score:  0.6675469230603018
#
# For K =  28
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.667941578373495
#
# For K =  29
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6687819125317122
#
# For K =  30
# R2: 0.742
# RMSE: 0.652
# Cross Validation Score:  0.6688792424568643
#
# For K =  31
# R2: 0.74
# RMSE: 0.654
# Cross Validation Score:  0.6686598228928875
#
# For K =  32
# R2: 0.739
# RMSE: 0.655
# Cross Validation Score:  0.6687541996202964
#
# For K =  33
# R2: 0.74
# RMSE: 0.654
# Cross Validation Score:  0.6685380412395185
#
# For K =  34
# R2: 0.739
# RMSE: 0.655
# Cross Validation Score:  0.6687269467648354
#
# For K =  35
# R2: 0.738
# RMSE: 0.656
# Cross Validation Score:  0.6693103882153577
#
# For K =  36
# R2: 0.737
# RMSE: 0.657
# Cross Validation Score:  0.6698531136252301
#
# For K =  37
# R2: 0.736
# RMSE: 0.658
# Cross Validation Score:  0.6702904966711805
#
# For K =  38
# R2: 0.737
# RMSE: 0.658
# Cross Validation Score:  0.6703787644535324
#
# For K =  39
# R2: 0.736
# RMSE: 0.658
# Cross Validation Score:  0.6706412084441377
#
# For K =  40
# R2: 0.737
# RMSE: 0.658
# Cross Validation Score:  0.6706667070376503
#
# For K =  41
# R2: 0.737
# RMSE: 0.658
# Cross Validation Score:  0.6706834870844498
#
# For K =  42
# R2: 0.737
# RMSE: 0.658
# Cross Validation Score:  0.6705810736318746
#
# For K =  43
# R2: 0.737
# RMSE: 0.657
# Cross Validation Score:  0.6705265779556175
#
# For K =  44
# R2: 0.738
# RMSE: 0.657
# Cross Validation Score:  0.6704138647537121
#
# For K =  45
# R2: 0.737
# RMSE: 0.657
# Cross Validation Score:  0.670663178499636
#
# For K =  46
# R2: 0.737
# RMSE: 0.658
# Cross Validation Score:  0.6707417214757059
#
# For K =  47
# R2: 0.736
# RMSE: 0.658
# Cross Validation Score:  0.6705143372480549
#
# For K =  48
# R2: 0.736
# RMSE: 0.659
# Cross Validation Score:  0.6704116545800866
#
# For K =  49
# R2: 0.737
# RMSE: 0.658
# Cross Validation Score:  0.6702805155417966
#
# RobustScaler()
# For K =  1
# R2: 0.589
# RMSE: 0.822
# Cross Validation Score:  0.40596102413212565
#
# For K =  2
# R2: 0.672
# RMSE: 0.735
# Cross Validation Score:  0.533928742310089
#
# For K =  3
# R2: 0.704
# RMSE: 0.697
# Cross Validation Score:  0.5818187552702068
#
# For K =  4
# R2: 0.715
# RMSE: 0.685
# Cross Validation Score:  0.6049906590329603
#
# For K =  5
# R2: 0.72
# RMSE: 0.679
# Cross Validation Score:  0.619048424784719
#
# For K =  6
# R2: 0.723
# RMSE: 0.675
# Cross Validation Score:  0.6302595800154712
#
# For K =  7
# R2: 0.725
# RMSE: 0.673
# Cross Validation Score:  0.6354495520975506
#
# For K =  8
# R2: 0.729
# RMSE: 0.667
# Cross Validation Score:  0.6405964944636715
#
# For K =  9
# R2: 0.731
# RMSE: 0.666
# Cross Validation Score:  0.6451485451265992
#
# For K =  10
# R2: 0.732
# RMSE: 0.664
# Cross Validation Score:  0.6498890097961112
#
# For K =  11
# R2: 0.735
# RMSE: 0.66
# Cross Validation Score:  0.6524647890920362
#
# For K =  12
# R2: 0.735
# RMSE: 0.661
# Cross Validation Score:  0.6552651118020297
#
# For K =  13
# R2: 0.737
# RMSE: 0.657
# Cross Validation Score:  0.6561851706262832
#
# For K =  14
# R2: 0.739
# RMSE: 0.655
# Cross Validation Score:  0.657754118257676
#
# For K =  15
# R2: 0.74
# RMSE: 0.653
# Cross Validation Score:  0.6598542460629663
#
# For K =  16
# R2: 0.74
# RMSE: 0.653
# Cross Validation Score:  0.6613778429649301
#
# For K =  17
# R2: 0.74
# RMSE: 0.653
# Cross Validation Score:  0.6626382272326852
#
# For K =  18
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6634755316447312
#
# For K =  19
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6636767997248071
#
# For K =  20
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6641432580115104
#
# For K =  21
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6649947453653379
#
# For K =  22
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6651769909383367
#
# For K =  23
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6658517805849665
#
# For K =  24
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.666489618453992
#
# For K =  25
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6668833090048651
#
# For K =  26
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6674637518798009
#
# For K =  27
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6675469230603018
#
# For K =  28
# R2: 0.743
# RMSE: 0.651
# Cross Validation Score:  0.667941578373495
#
# For K =  29
# R2: 0.744
# RMSE: 0.649
# Cross Validation Score:  0.6687819125317122
#
# For K =  30
# R2: 0.744
# RMSE: 0.649
# Cross Validation Score:  0.6688792424568643
#
# For K =  31
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6686598228928875
#
# For K =  32
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6687541996202964
#
# For K =  33
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6685380412395185
#
# For K =  34
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6687269467648354
#
# For K =  35
# R2: 0.743
# RMSE: 0.649
# Cross Validation Score:  0.6693103882153577
#
# For K =  36
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6698531136252301
#
# For K =  37
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6702904966711805
#
# For K =  38
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6703787644535324
#
# For K =  39
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6706412084441377
#
# For K =  40
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6706667070376503
#
# For K =  41
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6706834870844498
#
# For K =  42
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6705810736318746
#
# For K =  43
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6705265779556175
#
# For K =  44
# R2: 0.742
# RMSE: 0.652
# Cross Validation Score:  0.6704138647537121
#
# For K =  45
# R2: 0.742
# RMSE: 0.652
# Cross Validation Score:  0.670663178499636
#
# For K =  46
# R2: 0.741
# RMSE: 0.653
# Cross Validation Score:  0.6707417214757059
#
# For K =  47
# R2: 0.741
# RMSE: 0.653
# Cross Validation Score:  0.6705143372480549
#
# For K =  48
# R2: 0.741
# RMSE: 0.653
# Cross Validation Score:  0.6704116545800866
#
# For K =  49
# R2: 0.74
# RMSE: 0.653
# Cross Validation Score:  0.6702805155417966
#
# MinMaxScaler()
# For K =  1
# R2: 0.598
# RMSE: 0.813
# Cross Validation Score:  0.40596102413212565
#
# For K =  2
# R2: 0.68
# RMSE: 0.725
# Cross Validation Score:  0.533928742310089
#
# For K =  3
# R2: 0.713
# RMSE: 0.687
# Cross Validation Score:  0.5818187552702068
#
# For K =  4
# R2: 0.722
# RMSE: 0.676
# Cross Validation Score:  0.6049906590329603
#
# For K =  5
# R2: 0.726
# RMSE: 0.671
# Cross Validation Score:  0.619048424784719
#
# For K =  6
# R2: 0.73
# RMSE: 0.667
# Cross Validation Score:  0.6302595800154712
#
# For K =  7
# R2: 0.733
# RMSE: 0.662
# Cross Validation Score:  0.6354495520975506
#
# For K =  8
# R2: 0.736
# RMSE: 0.659
# Cross Validation Score:  0.6405964944636715
#
# For K =  9
# R2: 0.738
# RMSE: 0.657
# Cross Validation Score:  0.6451485451265992
#
# For K =  10
# R2: 0.74
# RMSE: 0.654
# Cross Validation Score:  0.6498890097961112
#
# For K =  11
# R2: 0.741
# RMSE: 0.652
# Cross Validation Score:  0.6524647890920362
#
# For K =  12
# R2: 0.741
# RMSE: 0.652
# Cross Validation Score:  0.6552651118020297
#
# For K =  13
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6561851706262832
#
# For K =  14
# R2: 0.744
# RMSE: 0.649
# Cross Validation Score:  0.657754118257676
#
# For K =  15
# R2: 0.745
# RMSE: 0.648
# Cross Validation Score:  0.6598542460629663
#
# For K =  16
# R2: 0.746
# RMSE: 0.647
# Cross Validation Score:  0.6613778429649301
#
# For K =  17
# R2: 0.747
# RMSE: 0.645
# Cross Validation Score:  0.6626382272326852
#
# For K =  18
# R2: 0.746
# RMSE: 0.646
# Cross Validation Score:  0.6634755316447312
#
# For K =  19
# R2: 0.745
# RMSE: 0.648
# Cross Validation Score:  0.6636767997248071
#
# For K =  20
# R2: 0.744
# RMSE: 0.649
# Cross Validation Score:  0.6641432580115104
#
# For K =  21
# R2: 0.744
# RMSE: 0.649
# Cross Validation Score:  0.6649947453653379
#
# For K =  22
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6651769909383367
#
# For K =  23
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6658517805849665
#
# For K =  24
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.666489618453992
#
# For K =  25
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6668833090048651
#
# For K =  26
# R2: 0.743
# RMSE: 0.65
# Cross Validation Score:  0.6674637518798009
#
# For K =  27
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6675469230603018
#
# For K =  28
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.667941578373495
#
# For K =  29
# R2: 0.742
# RMSE: 0.651
# Cross Validation Score:  0.6687819125317122
#
# For K =  30
# R2: 0.741
# RMSE: 0.652
# Cross Validation Score:  0.6688792424568643
#
# For K =  31
# R2: 0.741
# RMSE: 0.653
# Cross Validation Score:  0.6686598228928875
#
# For K =  32
# R2: 0.741
# RMSE: 0.653
# Cross Validation Score:  0.6687541996202964
#
# For K =  33
# R2: 0.741
# RMSE: 0.653
# Cross Validation Score:  0.6685380412395185
#
# For K =  34
# R2: 0.74
# RMSE: 0.654
# Cross Validation Score:  0.6687269467648354
#
# For K =  35
# R2: 0.739
# RMSE: 0.654
# Cross Validation Score:  0.6693103882153577
#
# For K =  36
# R2: 0.739
# RMSE: 0.655
# Cross Validation Score:  0.6698531136252301
#
# For K =  37
# R2: 0.739
# RMSE: 0.655
# Cross Validation Score:  0.6702904966711805
#
# For K =  38
# R2: 0.739
# RMSE: 0.655
# Cross Validation Score:  0.6703787644535324
#
# For K =  39
# R2: 0.739
# RMSE: 0.655
# Cross Validation Score:  0.6706412084441377
#
# For K =  40
# R2: 0.739
# RMSE: 0.655
# Cross Validation Score:  0.6706667070376503
#
# For K =  41
# R2: 0.739
# RMSE: 0.656
# Cross Validation Score:  0.6706834870844498
#
# For K =  42
# R2: 0.738
# RMSE: 0.657
# Cross Validation Score:  0.6705810736318746
#
# For K =  43
# R2: 0.737
# RMSE: 0.658
# Cross Validation Score:  0.6705265779556175
#
# For K =  44
# R2: 0.736
# RMSE: 0.658
# Cross Validation Score:  0.6704138647537121
#
# For K =  45
# R2: 0.735
# RMSE: 0.66
# Cross Validation Score:  0.670663178499636
#
# For K =  46
# R2: 0.734
# RMSE: 0.661
# Cross Validation Score:  0.6707417214757059
#
# For K =  47
# R2: 0.734
# RMSE: 0.661
# Cross Validation Score:  0.6705143372480549
#
# For K =  48
# R2: 0.733
# RMSE: 0.662
# Cross Validation Score:  0.6704116545800866
#
# For K =  49
# R2: 0.733
# RMSE: 0.663
# Cross Validation Score:  0.6702805155417966

# %% [markdown]
# **Tuning Hyperparameters**

# %%
range_list = [*range(10, 30, 1)]

X = cookies.drop(['quality'], axis=1)
y = cookies['quality']

scaler = StandardScaler()
scaler.fit(X)

X_scale = scaler.transform(X)

# Select an algorithm
algorithm = KNeighborsRegressor()

# Create 3 folds
seed = 13
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# Define our candidate hyperparameters
hp_candidates = [{'n_neighbors': range_list, 'weights': ['uniform','distance']}]

# Search for best hyperparameters
grid = GridSearchCV(estimator=algorithm, param_grid=hp_candidates, cv=kfold, scoring='r2')
grid.fit(X_scale, y)

# Get the results
print(grid.best_score_)
print(grid.best_estimator_)
print(grid.best_params_)
# Out:
# 0.7617068608088978
# KNeighborsRegressor(n_neighbors=27, weights='distance')
# {'n_neighbors': 27, 'weights': 'distance'}

# %%
grid.predict(X_test_scale)

# %%
#with Standard Scaler
from sklearn.neighbors import KNeighborsRegressor

X = cookies.drop('quality', axis=1)
y = cookies['quality']

X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.05, random_state=0)

#scaling the x values
scaler = StandardScaler()
scaler.fit(X_train)

X_scale = scaler.transform(X)

X_train_scale = scaler.transform(X_train)
X_test_scale = scaler.transform(X_test)

Knn = KNeighborsRegressor(n_neighbors = 27, weights = 'distance')

Knn.fit(X_train_scale, y_train)

y_pred = Knn.predict(X_test_scale)

print('R2:', round(r2_score(y_test, y_pred), 3))
print('RMSE:', round(mean_squared_error(y_test, y_pred, squared=False), 3))
print('Cross Validation Score: ', cross_val_score(Knn, X_scale, y, cv=10).mean())
# Out:
# R2: 0.782
# RMSE: 0.601
# Cross Validation Score:  0.7573852789203195

# %% [markdown]
# ## Saving Data

# %%
#transforming test data frame

test = pd.read_csv('../Data/cookies_validate.csv')

#dropping
test.drop('id', axis=1, inplace=True)
test.drop('quality', axis=1, inplace=True)
test.drop(['crunch factor', 'aesthetic appeal', 'diameter'], axis=1, inplace=True)

#making dummies
#butter types
test['butter type'] = test['butter type'].replace('melted', 1).replace('cubed', 0)

#mixins
mixins_list = ['chocolate', 'raisins', 'oats', 'nuts', 'peanut butter']

for x in mixins_list:
    test[x] = 0
    test[x] = test['mixins'].str.contains(x).astype(int)

test.drop('mixins', axis=1, inplace=True)

# %%
test.columns
# Out:
# Index(['sugar to flour ratio', 'sugar index', 'bake temp', 'chill time',
#        'calories', 'density', 'pH', 'grams baking soda', 'bake time',
