# %% [markdown]
# # Spotify API Scrapping

# %% [markdown]
# Playlists:
# - https://open.spotify.com/playlist/1G8IpkZKobrIlXcVPoSIuf
# - https://open.spotify.com/playlist/2YRe7HRKNRvXdJBp9nXFza

# %%
from config import *
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= Client_ID, client_secret=Client_Secret))

# %%
username = "spotify"

# %%
def get_playlist_info(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id) #gets playlist info
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
list_playlists = []

for playlist_id in playlist_ids:
    list_playlists.append(get_playlist_info(username, playlist_id))

# %%
def main(playlists):
    
    list_of_df = []

    for  playlist in playlists:   
        
        song_names = []
        song_uri_total = []
        artist_names = []
        audio_features = []
        song_uri = []
        counter = 0
        
        for item in playlist:
            if item["is_local"] == False:
                try: 
                    counter += 1
                    song_names.append(item['track']['name'])
                    song_uri_total.append(item['track']['uri'])
                    song_uri.append(item['track']['uri'])
                    
                    temp_artists = []
                    for artist in item['track']['artists']:
                        temp_artists.append(artist['name'])
                        
                    artist_names.append(temp_artists)
                    
                    if counter == 100:
                        audio_features.append(sp.audio_features(song_uri))
                        counter = 0
                        song_uri = []
                        
                except TypeError:
                    continue
    

        audio_features.append(sp.audio_features(song_uri))
        
        audio_features_total = [subitem for item in audio_features for subitem in item]
        
        df = pd.DataFrame({"song_name": song_names, "artist_name": artist_names, "uri": song_uri_total})
        
        df_features = pd.DataFrame(audio_features_total)
        
        spotify_df = df.merge(df_features, on="uri", how="left")
        
        list_of_df.append(spotify_df)
        
    return list_of_df

# %%
df_list = main(playlists=list_playlists)

# %%
#len(df_list[0])
# Out:
# 9947

# %%
#len(df_list[1])
# Out:
# 575

# %%
df_list[1]
# Out:
#                             song_name                        artist_name  \
# 0                        Shape of You                       [Ed Sheeran]
# 1                        Dance Monkey                      [Tones And I]
# 2          rockstar (feat. 21 Savage)           [Post Malone, 21 Savage]
# 3                     Blinding Lights                       [The Weeknd]
# 4                           One Dance              [Drake, WizKid, Kyla]
# ..                                ...                                ...
# 570                       Close To Me  [Ellie Goulding, Diplo, Swae Lee]
# 571         The Chain - 2004 Remaster                    [Fleetwood Mac]
# 572   Go Your Own Way - 2004 Remaster                    [Fleetwood Mac]
# 573                      Mr. Blue Sky         [Electric Light Orchestra]
# 574  Supalonely (feat. Gus Dapperton)             [BENEE, Gus Dapperton]
#
#                                       uri  danceability  energy  key  \
# 0    spotify:track:7qiZfU4dY1lWllzX7mPBI3         0.825   0.652    1
# 1    spotify:track:1rgnBhdG2JDFTbYkYRZAku         0.825   0.593    6
# 2    spotify:track:0e7ipj03S05BNilyu5bRzt         0.585   0.520    5
# 3    spotify:track:0VjIjW4GlUZAMYd2vXMi3b         0.514   0.730    1
# 4    spotify:track:12VWzyPDBCc8fqeWCAfNwR         0.792   0.625    1
# ..                                    ...           ...     ...  ...
# 570  spotify:track:2GjMaJ7DacMIkgoe8oMXGg         0.572   0.750    1
# 571  spotify:track:5e9TFTbltYBg2xThimr0rU         0.545   0.670    9
# 572  spotify:track:4xh7W7tlNMIczFhupCPniY         0.586   0.941    5
# 573  spotify:track:2RlgNHKcydI9sayD2Df2xp         0.388   0.338   10
# 574  spotify:track:3GZoWLVbmxcBys6g0DLFLf         0.862   0.631    7
#
#      loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0      -3.183     0       0.0802       0.58100          0.000000    0.0931
# 1      -6.401     0       0.0988       0.68800          0.000161    0.1700
# 2      -6.136     0       0.0712       0.12400          0.000070    0.1310
# 3      -5.934     1       0.0598       0.00146          0.000095    0.0897
# 4      -5.609     1       0.0536       0.00776          0.001880    0.3290
# ..        ...   ...          ...           ...               ...       ...
# 570    -5.042     0       0.0604       0.09460          0.000000    0.3780
# 571    -8.810     1       0.0496       0.00900          0.000822    0.0451
# 572    -5.139     1       0.0375       0.01670          0.000776    0.0680
# 573   -10.054     1       0.0329       0.65200          0.000004    0.2480
# 574    -4.746     1       0.0515       0.29100          0.000209    0.1230
#
#      valence    tempo            type                      id  \
# 0      0.931   95.977  audio_features  7qiZfU4dY1lWllzX7mPBI3
# 1      0.540   98.078  audio_features  1rgnBhdG2JDFTbYkYRZAku
# 2      0.129  159.801  audio_features  0e7ipj03S05BNilyu5bRzt
# 3      0.334  171.005  audio_features  0VjIjW4GlUZAMYd2vXMi3b
# 4      0.370  103.967  audio_features  12VWzyPDBCc8fqeWCAfNwR
# ..       ...      ...             ...                     ...
# 570    0.475  144.081  audio_features  2GjMaJ7DacMIkgoe8oMXGg
# 571    0.481  151.553  audio_features  5e9TFTbltYBg2xThimr0rU
# 572    0.831  135.448  audio_features  4xh7W7tlNMIczFhupCPniY
# 573    0.478  177.765  audio_features  2RlgNHKcydI9sayD2Df2xp
# 574    0.841  128.978  audio_features  3GZoWLVbmxcBys6g0DLFLf
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/7qiZfU4dY1lW...
# 1    https://api.spotify.com/v1/tracks/1rgnBhdG2JDF...
# 2    https://api.spotify.com/v1/tracks/0e7ipj03S05B...
# 3    https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# 4    https://api.spotify.com/v1/tracks/12VWzyPDBCc8...
# ..                                                 ...
# 570  https://api.spotify.com/v1/tracks/2GjMaJ7DacMI...
# 571  https://api.spotify.com/v1/tracks/5e9TFTbltYBg...
# 572  https://api.spotify.com/v1/tracks/4xh7W7tlNMIc...
# 573  https://api.spotify.com/v1/tracks/2RlgNHKcydI9...
# 574  https://api.spotify.com/v1/tracks/3GZoWLVbmxcB...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/7qiZ...       233713
# 1    https://api.spotify.com/v1/audio-analysis/1rgn...       209755
# 2    https://api.spotify.com/v1/audio-analysis/0e7i...       218147
# 3    https://api.spotify.com/v1/audio-analysis/0VjI...       200040
# 4    https://api.spotify.com/v1/audio-analysis/12VW...       173987
# ..                                                 ...          ...
# 570  https://api.spotify.com/v1/audio-analysis/2GjM...       182627
# 571  https://api.spotify.com/v1/audio-analysis/5e9T...       270213
# 572  https://api.spotify.com/v1/audio-analysis/4xh7...       223613
# 573  https://api.spotify.com/v1/audio-analysis/2Rlg...       303373
# 574  https://api.spotify.com/v1/audio-analysis/3GZo...       223488
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 570               4
# 571               4
# 572               4
# 573               4
# 574               4
#
# [575 rows x 20 columns]

# %%
pd.concat(df_list)
# Out:
#                             song_name                        artist_name  \
# 0                Like a Rolling Stone                        [Bob Dylan]
# 1             Smells Like Teen Spirit                          [Nirvana]
# 2      A Day In The Life - Remastered                      [The Beatles]
# 3              Good Vibrations (Mono)                   [The Beach Boys]
# 4                      Johnny B Goode                      [Chuck Berry]
# ..                                ...                                ...
# 570                       Close To Me  [Ellie Goulding, Diplo, Swae Lee]
# 571         The Chain - 2004 Remaster                    [Fleetwood Mac]
# 572   Go Your Own Way - 2004 Remaster                    [Fleetwood Mac]
# 573                      Mr. Blue Sky         [Electric Light Orchestra]
# 574  Supalonely (feat. Gus Dapperton)             [BENEE, Gus Dapperton]
#
#                                       uri  danceability  energy  key  \
# 0    spotify:track:3AhXZa8sUQht0UEdBJgpGc         0.483   0.721    0
# 1    spotify:track:3oTlkzk1OtrhH8wBAduVEi         0.485   0.863    1
# 2    spotify:track:3ZFBeIyP41HhnALjxWy1pR         0.364   0.457    4
# 3    spotify:track:5Qt4Cc66g24QWwGP3YYV9y         0.398   0.413    1
# 4    spotify:track:7MH2ZclofPlTrZOkPzZKhK         0.518   0.756   10
# ..                                    ...           ...     ...  ...
# 570  spotify:track:2GjMaJ7DacMIkgoe8oMXGg         0.572   0.750    1
# 571  spotify:track:5e9TFTbltYBg2xThimr0rU         0.545   0.670    9
# 572  spotify:track:4xh7W7tlNMIczFhupCPniY         0.586   0.941    5
# 573  spotify:track:2RlgNHKcydI9sayD2Df2xp         0.388   0.338   10
# 574  spotify:track:3GZoWLVbmxcBys6g0DLFLf         0.862   0.631    7
#
#      loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0      -6.836     1       0.0320      0.729000          0.000000    0.1890
# 1      -9.027     1       0.0495      0.000012          0.016200    0.1380
# 2     -14.162     0       0.0675      0.290000          0.000106    0.9220
# 3     -10.934     1       0.0388      0.082200          0.000025    0.0891
# 4     -10.851     1       0.0915      0.735000          0.000062    0.3170
# ..        ...   ...          ...           ...               ...       ...
# 570    -5.042     0       0.0604      0.094600          0.000000    0.3780
# 571    -8.810     1       0.0496      0.009000          0.000822    0.0451
# 572    -5.139     1       0.0375      0.016700          0.000776    0.0680
# 573   -10.054     1       0.0329      0.652000          0.000004    0.2480
# 574    -4.746     1       0.0515      0.291000          0.000209    0.1230
#
#      valence    tempo            type                      id  \
# 0      0.562   95.261  audio_features  3AhXZa8sUQht0UEdBJgpGc
# 1      0.767  116.835  audio_features  3oTlkzk1OtrhH8wBAduVEi
# 2      0.175  163.219  audio_features  3ZFBeIyP41HhnALjxWy1pR
# 3      0.331  133.574  audio_features  5Qt4Cc66g24QWwGP3YYV9y
# 4      0.968  166.429  audio_features  7MH2ZclofPlTrZOkPzZKhK
# ..       ...      ...             ...                     ...
# 570    0.475  144.081  audio_features  2GjMaJ7DacMIkgoe8oMXGg
# 571    0.481  151.553  audio_features  5e9TFTbltYBg2xThimr0rU
# 572    0.831  135.448  audio_features  4xh7W7tlNMIczFhupCPniY
# 573    0.478  177.765  audio_features  2RlgNHKcydI9sayD2Df2xp
# 574    0.841  128.978  audio_features  3GZoWLVbmxcBys6g0DLFLf
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/3AhXZa8sUQht...
# 1    https://api.spotify.com/v1/tracks/3oTlkzk1Otrh...
# 2    https://api.spotify.com/v1/tracks/3ZFBeIyP41Hh...
# 3    https://api.spotify.com/v1/tracks/5Qt4Cc66g24Q...
# 4    https://api.spotify.com/v1/tracks/7MH2ZclofPlT...
# ..                                                 ...
# 570  https://api.spotify.com/v1/tracks/2GjMaJ7DacMI...
# 571  https://api.spotify.com/v1/tracks/5e9TFTbltYBg...
# 572  https://api.spotify.com/v1/tracks/4xh7W7tlNMIc...
# 573  https://api.spotify.com/v1/tracks/2RlgNHKcydI9...
# 574  https://api.spotify.com/v1/tracks/3GZoWLVbmxcB...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/3AhX...       369600
# 1    https://api.spotify.com/v1/audio-analysis/3oTl...       300977
# 2    https://api.spotify.com/v1/audio-analysis/3ZFB...       337413
# 3    https://api.spotify.com/v1/audio-analysis/5Qt4...       219147
# 4    https://api.spotify.com/v1/audio-analysis/7MH2...       160893
# ..                                                 ...          ...
# 570  https://api.spotify.com/v1/audio-analysis/2GjM...       182627
# 571  https://api.spotify.com/v1/audio-analysis/5e9T...       270213
# 572  https://api.spotify.com/v1/audio-analysis/4xh7...       223613
# 573  https://api.spotify.com/v1/audio-analysis/2Rlg...       303373
# 574  https://api.spotify.com/v1/audio-analysis/3GZo...       223488
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 570               4
# 571               4
# 572               4
# 573               4
# 574               4
#
# [10522 rows x 20 columns]

# %%
#audio_features_total = [subitem for item in audio_features for subitem in item]

# %%
#df = pd.DataFrame({"song_name": song_names, "artist_name": artist_names, "uri": song_uri_total})

# %%
df.tail()
# Out:
#                               song_name                        artist_name  \
# 10517                       Close To Me  [Ellie Goulding, Diplo, Swae Lee]
# 10518         The Chain - 2004 Remaster                    [Fleetwood Mac]
# 10519   Go Your Own Way - 2004 Remaster                    [Fleetwood Mac]
# 10520                      Mr. Blue Sky         [Electric Light Orchestra]
# 10521  Supalonely (feat. Gus Dapperton)             [BENEE, Gus Dapperton]
#
#                                         uri
# 10517  spotify:track:2GjMaJ7DacMIkgoe8oMXGg
# 10518  spotify:track:5e9TFTbltYBg2xThimr0rU
# 10519  spotify:track:4xh7W7tlNMIczFhupCPniY
# 10520  spotify:track:2RlgNHKcydI9sayD2Df2xp
# 10521  spotify:track:3GZoWLVbmxcBys6g0DLFLf

# %%
len(audio_features_total)
# Out:
# 10571

# %%
#df_features = pd.DataFrame(audio_features_total)

# %%
df_features.tail()
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 10566         0.572   0.750    1    -5.042     0       0.0604        0.0946
# 10567         0.545   0.670    9    -8.810     1       0.0496        0.0090
# 10568         0.586   0.941    5    -5.139     1       0.0375        0.0167
# 10569         0.388   0.338   10   -10.054     1       0.0329        0.6520
# 10570         0.862   0.631    7    -4.746     1       0.0515        0.2910
#
#        instrumentalness  liveness  valence    tempo            type  \
# 10566          0.000000    0.3780    0.475  144.081  audio_features
# 10567          0.000822    0.0451    0.481  151.553  audio_features
# 10568          0.000776    0.0680    0.831  135.448  audio_features
# 10569          0.000004    0.2480    0.478  177.765  audio_features
# 10570          0.000209    0.1230    0.841  128.978  audio_features
#
#                            id                                   uri  \
# 10566  2GjMaJ7DacMIkgoe8oMXGg  spotify:track:2GjMaJ7DacMIkgoe8oMXGg
# 10567  5e9TFTbltYBg2xThimr0rU  spotify:track:5e9TFTbltYBg2xThimr0rU
# 10568  4xh7W7tlNMIczFhupCPniY  spotify:track:4xh7W7tlNMIczFhupCPniY
# 10569  2RlgNHKcydI9sayD2Df2xp  spotify:track:2RlgNHKcydI9sayD2Df2xp
# 10570  3GZoWLVbmxcBys6g0DLFLf  spotify:track:3GZoWLVbmxcBys6g0DLFLf
#
#                                               track_href  \
# 10566  https://api.spotify.com/v1/tracks/2GjMaJ7DacMI...
# 10567  https://api.spotify.com/v1/tracks/5e9TFTbltYBg...
# 10568  https://api.spotify.com/v1/tracks/4xh7W7tlNMIc...
# 10569  https://api.spotify.com/v1/tracks/2RlgNHKcydI9...
# 10570  https://api.spotify.com/v1/tracks/3GZoWLVbmxcB...
#
#                                             analysis_url  duration_ms  \
# 10566  https://api.spotify.com/v1/audio-analysis/2GjM...       182627
# 10567  https://api.spotify.com/v1/audio-analysis/5e9T...       270213
# 10568  https://api.spotify.com/v1/audio-analysis/4xh7...       223613
# 10569  https://api.spotify.com/v1/audio-analysis/2Rlg...       303373
# 10570  https://api.spotify.com/v1/audio-analysis/3GZo...       223488
#
#        time_signature
# 10566               4
# 10567               4
# 10568               4
# 10569               4
# 10570               4

# %%
df_features.drop(columns=['track_href', 'analysis_url', 'type', 'id'], inplace=True)

# %%
#spotify_df = pd.concat([df, df_features], axis = 1, join="inner")

# %%
spotify_df.tail()
# Out:
#                               song_name                        artist_name  \
# 10517                       Close To Me  [Ellie Goulding, Diplo, Swae Lee]
# 10518         The Chain - 2004 Remaster                    [Fleetwood Mac]
# 10519   Go Your Own Way - 2004 Remaster                    [Fleetwood Mac]
# 10520                      Mr. Blue Sky         [Electric Light Orchestra]
# 10521  Supalonely (feat. Gus Dapperton)             [BENEE, Gus Dapperton]
#
#                                         uri  danceability  energy  key  \
# 10517  spotify:track:2GjMaJ7DacMIkgoe8oMXGg         0.806   0.546    9
# 10518  spotify:track:5e9TFTbltYBg2xThimr0rU         0.475   0.370    4
# 10519  spotify:track:4xh7W7tlNMIczFhupCPniY         0.483   0.412    7
# 10520  spotify:track:2RlgNHKcydI9sayD2Df2xp         0.671   0.771    7
# 10521  spotify:track:3GZoWLVbmxcBys6g0DLFLf         0.557   0.540    9
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 10517    -6.637     1       0.0575       0.30000          0.000000    0.1020
# 10518    -7.725     0       0.0361       0.81900          0.057700    0.0841
# 10519    -8.461     1       0.0402       0.73700          0.000000    0.1160
# 10520    -4.821     0       0.0316       0.00492          0.000007    0.3540
# 10521   -10.484     1       0.0347       0.03390          0.002480    0.1790
#
#        valence    tempo                                   uri  duration_ms  \
# 10517    0.874  147.986  spotify:track:4umIPjkehX1r7uhmGvXiSV       212867
# 10518    0.157  144.828  spotify:track:2uIX8YMNjGMD7441kqyyNU       200560
# 10519    0.247  170.163  spotify:track:41zXlQxzTi6cGAjpOXyLYH       203569
# 10520    0.436   90.003  spotify:track:27tNWlhdAryQY04Gb2ZhUI       223546
# 10521    0.394  129.171  spotify:track:6dGnYIeXmHdcikdzNNDMm2       185733
#
#        time_signature
# 10517               4
# 10518               4
# 10519               3
# 10520               4
# 10521               4

# %%
spotify_df.shape
# Out:
# (10522, 17)

# %%
spotify_df.loc[spotify_df.astype(str).drop_duplicates().index]
# Out:
#                               song_name                        artist_name  \
# 0                  Like a Rolling Stone                        [Bob Dylan]
# 1               Smells Like Teen Spirit                          [Nirvana]
# 2        A Day In The Life - Remastered                      [The Beatles]
# 3                Good Vibrations (Mono)                   [The Beach Boys]
# 4                        Johnny B Goode                      [Chuck Berry]
# ...                                 ...                                ...
# 10517                       Close To Me  [Ellie Goulding, Diplo, Swae Lee]
# 10518         The Chain - 2004 Remaster                    [Fleetwood Mac]
# 10519   Go Your Own Way - 2004 Remaster                    [Fleetwood Mac]
# 10520                      Mr. Blue Sky         [Electric Light Orchestra]
# 10521  Supalonely (feat. Gus Dapperton)             [BENEE, Gus Dapperton]
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:3AhXZa8sUQht0UEdBJgpGc         0.483   0.721    0
# 1      spotify:track:3oTlkzk1OtrhH8wBAduVEi         0.485   0.863    1
# 2      spotify:track:3ZFBeIyP41HhnALjxWy1pR         0.364   0.457    4
# 3      spotify:track:5Qt4Cc66g24QWwGP3YYV9y         0.398   0.413    1
# 4      spotify:track:7MH2ZclofPlTrZOkPzZKhK         0.518   0.756   10
# ...                                     ...           ...     ...  ...
# 10517  spotify:track:2GjMaJ7DacMIkgoe8oMXGg         0.806   0.546    9
# 10518  spotify:track:5e9TFTbltYBg2xThimr0rU         0.475   0.370    4
# 10519  spotify:track:4xh7W7tlNMIczFhupCPniY         0.483   0.412    7
# 10520  spotify:track:2RlgNHKcydI9sayD2Df2xp         0.671   0.771    7
# 10521  spotify:track:3GZoWLVbmxcBys6g0DLFLf         0.557   0.540    9
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0        -6.836     1       0.0320      0.729000          0.000000    0.1890
# 1        -9.027     1       0.0495      0.000012          0.016200    0.1380
# 2       -14.162     0       0.0675      0.290000          0.000106    0.9220
# 3       -10.934     1       0.0388      0.082200          0.000025    0.0891
# 4       -10.851     1       0.0915      0.735000          0.000062    0.3170
# ...         ...   ...          ...           ...               ...       ...
# 10517    -6.637     1       0.0575      0.300000          0.000000    0.1020
# 10518    -7.725     0       0.0361      0.819000          0.057700    0.0841
# 10519    -8.461     1       0.0402      0.737000          0.000000    0.1160
# 10520    -4.821     0       0.0316      0.004920          0.000007    0.3540
# 10521   -10.484     1       0.0347      0.033900          0.002480    0.1790
#
#        valence    tempo                                   uri  duration_ms  \
# 0        0.562   95.261  spotify:track:3AhXZa8sUQht0UEdBJgpGc       369600
# 1        0.767  116.835  spotify:track:3oTlkzk1OtrhH8wBAduVEi       300977
# 2        0.175  163.219  spotify:track:3ZFBeIyP41HhnALjxWy1pR       337413
# 3        0.331  133.574  spotify:track:5Qt4Cc66g24QWwGP3YYV9y       219147
# 4        0.968  166.429  spotify:track:7MH2ZclofPlTrZOkPzZKhK       160893
# ...        ...      ...                                   ...          ...
# 10517    0.874  147.986  spotify:track:4umIPjkehX1r7uhmGvXiSV       212867
# 10518    0.157  144.828  spotify:track:2uIX8YMNjGMD7441kqyyNU       200560
# 10519    0.247  170.163  spotify:track:41zXlQxzTi6cGAjpOXyLYH       203569
# 10520    0.436   90.003  spotify:track:27tNWlhdAryQY04Gb2ZhUI       223546
# 10521    0.394  129.171  spotify:track:6dGnYIeXmHdcikdzNNDMm2       185733
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 10517               4
# 10518               4
# 10519               3
# 10520               4
# 10521               4
#
# [10522 rows x 17 columns]

# %%
spotify_df.tail(150)
# Out:
#                                  song_name                        artist_name  \
# 10372          Goodbyes (feat. Young Thug)          [Post Malone, Young Thug]
# 10373                       God is a woman                    [Ariana Grande]
# 10374  Perfect Duet (Ed Sheeran & Beyoncé)              [Ed Sheeran, Beyoncé]
# 10375                                 Rise          [Jonas Blue, Jack & Jack]
# 10376                     A Thousand Years                  [Christina Perri]
# ...                                    ...                                ...
# 10517                          Close To Me  [Ellie Goulding, Diplo, Swae Lee]
# 10518            The Chain - 2004 Remaster                    [Fleetwood Mac]
# 10519      Go Your Own Way - 2004 Remaster                    [Fleetwood Mac]
# 10520                         Mr. Blue Sky         [Electric Light Orchestra]
# 10521     Supalonely (feat. Gus Dapperton)             [BENEE, Gus Dapperton]
#
#                                         uri  danceability  energy  key  \
# 10372  spotify:track:0t3ZvGKlmYmVsDzBJAXK8C         0.589   0.731    2
# 10373  spotify:track:5OCJzvD7sykQEKHH7qAC3C         0.815   0.438    0
# 10374  spotify:track:1bhUWB0zJMIKr9yVPrkEuI         0.733   0.892    0
# 10375  spotify:track:5ZSl6gDoV6bPPxzmLeneV9         0.567   0.913    8
# 10376  spotify:track:6lanRgr6wXibZr8KgzXxBl         0.922   0.581   10
# ...                                     ...           ...     ...  ...
# 10517  spotify:track:2GjMaJ7DacMIkgoe8oMXGg         0.806   0.546    9
# 10518  spotify:track:5e9TFTbltYBg2xThimr0rU         0.475   0.370    4
# 10519  spotify:track:4xh7W7tlNMIczFhupCPniY         0.483   0.412    7
# 10520  spotify:track:2RlgNHKcydI9sayD2Df2xp         0.671   0.771    7
# 10521  spotify:track:3GZoWLVbmxcBys6g0DLFLf         0.557   0.540    9
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 10372    -6.343     1       0.0868       0.05340          0.000000    0.3080
# 10373   -14.522     0       0.0346       0.21600          0.000466    0.0787
# 10374    -3.641     1       0.0417       0.03760          0.000000    0.1370
# 10375    -6.471     1       0.0736       0.09340          0.000124    0.1140
# 10376    -7.495     1       0.2700       0.00104          0.000059    0.1050
# ...         ...   ...          ...           ...               ...       ...
# 10517    -6.637     1       0.0575       0.30000          0.000000    0.1020
# 10518    -7.725     0       0.0361       0.81900          0.057700    0.0841
# 10519    -8.461     1       0.0402       0.73700          0.000000    0.1160
# 10520    -4.821     0       0.0316       0.00492          0.000007    0.3540
# 10521   -10.484     1       0.0347       0.03390          0.002480    0.1790
#
#        valence    tempo                                   uri  duration_ms  \
# 10372    0.191   87.908  spotify:track:5k38wzpLb15YgncyWdTZE4       268867
# 10373    0.552  108.965  spotify:track:2HHtWyy5CgaQbC7XSoOb0e       243773
# 10374    0.675   95.989  spotify:track:2hl6q70unbviGo3g1R7uFx       173720
# 10375    0.792   93.350  spotify:track:1cTZMwcBJT0Ka3UJPXOeeN       210926
# 10376    0.595  140.022  spotify:track:4qKcDkK6siZ7Jp1Jb4m0aL       181263
# ...        ...      ...                                   ...          ...
# 10517    0.874  147.986  spotify:track:4umIPjkehX1r7uhmGvXiSV       212867
# 10518    0.157  144.828  spotify:track:2uIX8YMNjGMD7441kqyyNU       200560
# 10519    0.247  170.163  spotify:track:41zXlQxzTi6cGAjpOXyLYH       203569
# 10520    0.436   90.003  spotify:track:27tNWlhdAryQY04Gb2ZhUI       223546
# 10521    0.394  129.171  spotify:track:6dGnYIeXmHdcikdzNNDMm2       185733
#
#        time_signature
# 10372               4
# 10373               4
# 10374               4
# 10375               4
# 10376               4
# ...               ...
# 10517               4
# 10518               4
# 10519               3
# 10520               4
# 10521               4
#
# [150 rows x 17 columns]

# %%
#spotify_df.to_csv("spotify_df.csv")
