# %% [markdown]
# # Clustering Spotify Tracks

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
spotify = pd.read_csv("../data/spotify_df.csv")

# %%
spotify.head(3)
# Out:
#    Unnamed: 0                       song_name   artist_name  \
# 0           0            like a rolling stone    bob dylan
# 1           1         smells like teen spirit      nirvana
# 2           2  a day in the life - remastered  the beatles
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:3ahxza8suqht0uedbjgpgc         0.483   0.721    0    -6.836
# 1  spotify:track:3otlkzk1otrhh8wbaduvei         0.485   0.863    1    -9.027
# 2  spotify:track:3zfbeiyp41hhnaljxwy1pr         0.364   0.457    4   -14.162
#
#    mode  speechiness  ...  instrumentalness  liveness  valence    tempo  \
# 0     1       0.0320  ...          0.000000     0.189    0.562   95.261
# 1     1       0.0495  ...          0.016200     0.138    0.767  116.835
# 2     0       0.0675  ...          0.000106     0.922    0.175  163.219
#
#              type                      id  \
# 0  audio_features  3ahxza8suqht0uedbjgpgc
# 1  audio_features  3otlkzk1otrhh8wbaduvei
# 2  audio_features  3zfbeiyp41hhnaljxwy1pr
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3ahxza8suqht...
# 1  https://api.spotify.com/v1/tracks/3otlkzk1otrh...
# 2  https://api.spotify.com/v1/tracks/3zfbeiyp41hh...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3ahx...      369600
# 1  https://api.spotify.com/v1/audio-analysis/3otl...      300977
# 2  https://api.spotify.com/v1/audio-analysis/3zfb...      337413
#
#    time_signature
# 0               4
# 1               4
# 2               4
#
# [3 rows x 21 columns]

# %%
clustering = spotify[['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]

# %%
clustering.head(3)
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.483   0.721    0    -6.836       0.0320      0.729000
# 1         0.485   0.863    1    -9.027       0.0495      0.000012
# 2         0.364   0.457    4   -14.162       0.0675      0.290000
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000000     0.189    0.562   95.261
# 1          0.016200     0.138    0.767  116.835
# 2          0.000106     0.922    0.175  163.219

# %%
clustering_prep = StandardScaler().fit_transform(clustering)

# %%
pd.DataFrame(clustering_prep, columns=clustering.columns).head(3)
# Out:
#    danceability    energy       key  loudness  speechiness  acousticness  \
# 0     -0.626655  0.397380 -1.486179  0.511578    -0.542765      1.454982
# 1     -0.614606  1.029298 -1.205486 -0.070527    -0.323047     -0.898645
# 2     -1.343579 -0.777453 -0.363405 -1.434793    -0.097052      0.037616
#
#    instrumentalness  liveness   valence     tempo
# 0         -0.428394  0.021267 -0.002438 -0.950378
# 1         -0.362733 -0.320200  0.818807 -0.163322
# 2         -0.427965  4.929008 -1.552788  1.528845

# %%
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(clustering_prep)
    inertia.append(kmeans.inertia_)

# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(clustering_prep)
    silhouette.append(silhouette_score(clustering_prep, kmeans.predict(clustering_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
#testing for inertia scores

score_list = []
for i in range(2,10):
    kmeans_model = KMeans(n_clusters=i, random_state=1234).fit(clustering_prep)
    preds = kmeans_model.predict(clustering_prep)
    score_list.append(kmeans_model.inertia_)

# %%
print(score_list)
# Out:
# [104529.56644284463, 94979.71702847925, 86121.14902754127, 79054.23353588107, 74134.10945281775, 70231.35743412732, 67389.27302948588, 64644.72495406246]

# %%
kmeans = KMeans(n_clusters=6, random_state=1234)
kmeans.fit(clustering_prep)
# Out:
# KMeans(n_clusters=6, random_state=1234)

# %%
clusters = kmeans.predict(clustering_prep)
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     959
# 1    1155
# 2    2549
# 3    4102
# 4    1116
# 5    2706
# dtype: int64

# %%
# visualize clusters on principle components
plt.title('K-Means Clustering with K=6')
plt.scatter(clustering_prep[:,0], clustering_prep[:,1], s=40, c=kmeans.labels_, cmap=plt.cm.prism)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], marker='+', s=100, c='k', linewidth=2)

# %%
spotify_df = pd.DataFrame(spotify)
spotify_df['cluster'] = clusters
pd.to_numeric(spotify_df['cluster'])
spotify_df
# Out:
#        Unnamed: 0                                         song_name  \
# 0               0                              like a rolling stone
# 1               1                           smells like teen spirit
# 2               2                    a day in the life - remastered
# 3               3                            good vibrations (mono)
# 4               4                                    johnny b goode
# ...           ...                                               ...
# 12582          45                                           colours
# 12583          46                              famous enough to die
# 12584          47  a billion heartbeats - child of the parish remix
# 12585          48                                        h34t rises
# 12586          49                                             4ever
#
#                              artist_name  \
# 0                             bob dylan
# 1                               nirvana
# 2                           the beatles
# 3                        the beach boys
# 4                           chuck berry
# ...                                  ...
# 12582                         josie man
# 12583                    oscar scheller
# 12584  mystery jets child of the parish
# 12585                     nilüfer yanya
# 12586                            clairo
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:3ahxza8suqht0uedbjgpgc         0.483   0.721    0
# 1      spotify:track:3otlkzk1otrhh8wbaduvei         0.485   0.863    1
# 2      spotify:track:3zfbeiyp41hhnaljxwy1pr         0.364   0.457    4
# 3      spotify:track:5qt4cc66g24qwwgp3yyv9y         0.398   0.413    1
# 4      spotify:track:7mh2zclofpltrzokpzzkhk         0.518   0.756   10
# ...                                     ...           ...     ...  ...
# 12582  spotify:track:3pr0jefk308qvzuqcij5jm         0.793   0.694    2
# 12583  spotify:track:0hskyjt75tyab0qxtfe2fd         0.813   0.690    7
# 12584  spotify:track:4yk3sromxb1c9virzdwlj0         0.599   0.809   11
# 12585  spotify:track:5rf4kmzzivt3x5z0oypumb         0.612   0.925    0
# 12586  spotify:track:5miospuqdxchvy0jb5no9q         0.750   0.585    9
#
#        loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 0        -6.836     1       0.0320  ...    0.1890    0.562   95.261
# 1        -9.027     1       0.0495  ...    0.1380    0.767  116.835
# 2       -14.162     0       0.0675  ...    0.9220    0.175  163.219
# 3       -10.934     1       0.0388  ...    0.0891    0.331  133.574
# 4       -10.851     1       0.0915  ...    0.3170    0.968  166.429
# ...         ...   ...          ...  ...       ...      ...      ...
# 12582    -5.011     1       0.0362  ...    0.0812    0.677  105.015
# 12583    -4.018     1       0.0433  ...    0.0832    0.967  125.012
# 12584    -5.799     1       0.0322  ...    0.1200    0.502  125.078
# 12585    -4.493     1       0.0507  ...    0.1180    0.462   87.970
# 12586    -7.576     0       0.0285  ...    0.1550    0.584  102.331
#
#                  type                      id  \
# 0      audio_features  3ahxza8suqht0uedbjgpgc
# 1      audio_features  3otlkzk1otrhh8wbaduvei
# 2      audio_features  3zfbeiyp41hhnaljxwy1pr
# 3      audio_features  5qt4cc66g24qwwgp3yyv9y
# 4      audio_features  7mh2zclofpltrzokpzzkhk
# ...               ...                     ...
# 12582  audio_features  3pr0jefk308qvzuqcij5jm
# 12583  audio_features  0hskyjt75tyab0qxtfe2fd
# 12584  audio_features  4yk3sromxb1c9virzdwlj0
# 12585  audio_features  5rf4kmzzivt3x5z0oypumb
# 12586  audio_features  5miospuqdxchvy0jb5no9q
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/3ahxza8suqht...
# 1      https://api.spotify.com/v1/tracks/3otlkzk1otrh...
# 2      https://api.spotify.com/v1/tracks/3zfbeiyp41hh...
# 3      https://api.spotify.com/v1/tracks/5qt4cc66g24q...
# 4      https://api.spotify.com/v1/tracks/7mh2zclofplt...
# ...                                                  ...
# 12582  https://api.spotify.com/v1/tracks/3pr0jefk308q...
# 12583  https://api.spotify.com/v1/tracks/0hskyjt75tya...
# 12584  https://api.spotify.com/v1/tracks/4yk3sromxb1c...
# 12585  https://api.spotify.com/v1/tracks/5rf4kmzzivt3...
# 12586  https://api.spotify.com/v1/tracks/5miospuqdxch...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/3ahx...      369600
# 1      https://api.spotify.com/v1/audio-analysis/3otl...      300977
# 2      https://api.spotify.com/v1/audio-analysis/3zfb...      337413
# 3      https://api.spotify.com/v1/audio-analysis/5qt4...      219147
# 4      https://api.spotify.com/v1/audio-analysis/7mh2...      160893
# ...                                                  ...         ...
# 12582  https://api.spotify.com/v1/audio-analysis/3pr0...      231037
# 12583  https://api.spotify.com/v1/audio-analysis/0hsk...      166173
# 12584  https://api.spotify.com/v1/audio-analysis/4yk3...      256157
# 12585  https://api.spotify.com/v1/audio-analysis/5rf4...      170539
# 12586  https://api.spotify.com/v1/audio-analysis/5mio...      159595
#
#       time_signature  cluster
# 0                  4        3
# 1                  4        3
# 2                  4        4
# 3                  4        5
# 4                  4        3
# ...              ...      ...
# 12582              4        3
# 12583              4        3
# 12584              4        5
# 12585              4        3
# 12586              4        3
#
# [12587 rows x 22 columns]

# %% [markdown]
# **Songs in the Clusters**

# %%
spotify_df[['song_name', 'artist_name']].loc[spotify_df['cluster']==0].head(10)
# Out:
#                                        song_name  \
# 21                        sympathy for the devil
# 25   the message (feat. melle mel & duke bootee)
# 36                   crazy in love (feat. jay-z)
# 50                               get ur freak on
# 64                               fight the power
# 67                   whole lotta love - remaster
# 68                                       alright
# 72                                   99 problems
# 74                                     formation
# 117              rapper's delight - long version
#
#                                            artist_name
# 21                                 the rolling stones
# 25   grandmaster flash & the furious five grandmast...
# 36                                      beyoncé jay-z
# 50                                      missy elliott
# 64                                       public enemy
# 67                                       led zeppelin
# 68                                     kendrick lamar
# 72                                              jay-z
# 74                                            beyoncé
# 117                                the sugarhill gang

# %%
spotify_df[['song_name', 'artist_name']].loc[spotify_df['cluster']==1].head(10)
# Out:
#                          song_name                   artist_name
# 14         love will tear us apart                 joy division
# 29          heroes - 1999 remaster                  david bowie
# 37               seven nation army            the white stripes
# 41                     blue monday                    new order
# 42                     purple haze                 jimi hendrix
# 53                     i feel love                 donna summer
# 77                  all my friends              lcd soundsystem
# 82                        oblivion                       grimes
# 91   ghost town - extended version                 the specials
# 100                         heroin  the velvet underground nico

# %%
spotify_df[['song_name', 'artist_name']].loc[spotify_df['cluster']==2].head(10)
# Out:
#                                            song_name              artist_name
# 11                                  heartbreak hotel           elvis presley
# 16                  (sittin' on) the dock of the bay            otis redding
# 22            strawberry fields forever - remastered             the beatles
# 24                                stairway to heaven            led zeppelin
# 26                                      what'd i say             ray charles
# 27                         imagine - remastered 2010             john lennon
# 28                            a change is gonna come               sam cooke
# 34                                     strange fruit          billie holiday
# 40               bohemian rhapsody - remastered 2011                   queen
# 46  you've lost that lovin' feelin' - single version  the righteous brothers

# %%
spotify_df[['song_name', 'artist_name']].loc[spotify_df['cluster']==3].head(10)
# Out:
#                                             song_name          artist_name
# 0                                like a rolling stone           bob dylan
# 1                             smells like teen spirit             nirvana
# 4                                      johnny b goode         chuck berry
# 5                                             respect     aretha franklin
# 6                                          be my baby        the ronettes
# 8                    i heard it through the grapevine         marvin gaye
# 9   (i can't get no) satisfaction - mono version /...  the rolling stones
# 10                                        billie jean     michael jackson
# 17                     hey ya! - radio mix / club mix             outkast
# 20                                     london calling           the clash

# %%
spotify_df[['song_name', 'artist_name']].loc[spotify_df['cluster']==4].head(10)
# Out:
#                                       song_name      artist_name
# 2                a day in the life - remastered     the beatles
# 19                                 paper planes          m.i.a.
# 30                               when doves cry          prince
# 57                           mr. tambourine man       the byrds
# 58                        bitter sweet symphony       the verve
# 62  unfinished sympathy - 2006 digital remaster  massive attack
# 63                                        loser            beck
# 65           once in a lifetime - 2005 remaster   talking heads
# 81                                    hound dog   elvis presley
# 83        i want to hold your hand - remastered     the beatles

# %%
spotify_df[['song_name', 'artist_name']].loc[spotify_df['cluster']==5].head(10)
# Out:
#                                 song_name         artist_name
# 3                  good vibrations (mono)     the beach boys
# 7                         what's going on        marvin gaye
# 12                            born to run  bruce springsteen
# 13  my generation - original mono version            the who
# 15     god only knows - mono / remastered     the beach boys
# 18    anarchy in the uk - remastered 2012        sex pistols
# 32                          common people               pulp
# 39                     god save the queen        sex pistols
# 47                  hey jude - remastered        the beatles
# 48               waterloo sunset - stereo          the kinks

# %%
spotify_df.loc[spotify_df['song_name']== 'Holocene']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, song_name, artist_name, uri, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, track_href, analysis_url, duration_ms, time_signature, cluster]
# Index: []
#
# [0 rows x 22 columns]

# %%
spotify_df.explode('artist_name')
# Out:
#        Unnamed: 0                                         song_name  \
# 0               0                              like a rolling stone
# 1               1                           smells like teen spirit
# 2               2                    a day in the life - remastered
# 3               3                            good vibrations (mono)
# 4               4                                    johnny b goode
# ...           ...                                               ...
# 12582          45                                           colours
# 12583          46                              famous enough to die
# 12584          47  a billion heartbeats - child of the parish remix
# 12585          48                                        h34t rises
# 12586          49                                             4ever
#
#                              artist_name  \
# 0                             bob dylan
# 1                               nirvana
# 2                           the beatles
# 3                        the beach boys
# 4                           chuck berry
# ...                                  ...
# 12582                         josie man
# 12583                    oscar scheller
# 12584  mystery jets child of the parish
# 12585                     nilüfer yanya
# 12586                            clairo
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:3ahxza8suqht0uedbjgpgc         0.483   0.721    0
# 1      spotify:track:3otlkzk1otrhh8wbaduvei         0.485   0.863    1
# 2      spotify:track:3zfbeiyp41hhnaljxwy1pr         0.364   0.457    4
# 3      spotify:track:5qt4cc66g24qwwgp3yyv9y         0.398   0.413    1
# 4      spotify:track:7mh2zclofpltrzokpzzkhk         0.518   0.756   10
# ...                                     ...           ...     ...  ...
# 12582  spotify:track:3pr0jefk308qvzuqcij5jm         0.793   0.694    2
# 12583  spotify:track:0hskyjt75tyab0qxtfe2fd         0.813   0.690    7
# 12584  spotify:track:4yk3sromxb1c9virzdwlj0         0.599   0.809   11
# 12585  spotify:track:5rf4kmzzivt3x5z0oypumb         0.612   0.925    0
# 12586  spotify:track:5miospuqdxchvy0jb5no9q         0.750   0.585    9
#
#        loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 0        -6.836     1       0.0320  ...    0.1890    0.562   95.261
# 1        -9.027     1       0.0495  ...    0.1380    0.767  116.835
# 2       -14.162     0       0.0675  ...    0.9220    0.175  163.219
# 3       -10.934     1       0.0388  ...    0.0891    0.331  133.574
# 4       -10.851     1       0.0915  ...    0.3170    0.968  166.429
# ...         ...   ...          ...  ...       ...      ...      ...
# 12582    -5.011     1       0.0362  ...    0.0812    0.677  105.015
# 12583    -4.018     1       0.0433  ...    0.0832    0.967  125.012
# 12584    -5.799     1       0.0322  ...    0.1200    0.502  125.078
# 12585    -4.493     1       0.0507  ...    0.1180    0.462   87.970
# 12586    -7.576     0       0.0285  ...    0.1550    0.584  102.331
#
#                  type                      id  \
# 0      audio_features  3ahxza8suqht0uedbjgpgc
# 1      audio_features  3otlkzk1otrhh8wbaduvei
# 2      audio_features  3zfbeiyp41hhnaljxwy1pr
# 3      audio_features  5qt4cc66g24qwwgp3yyv9y
# 4      audio_features  7mh2zclofpltrzokpzzkhk
# ...               ...                     ...
# 12582  audio_features  3pr0jefk308qvzuqcij5jm
# 12583  audio_features  0hskyjt75tyab0qxtfe2fd
# 12584  audio_features  4yk3sromxb1c9virzdwlj0
# 12585  audio_features  5rf4kmzzivt3x5z0oypumb
# 12586  audio_features  5miospuqdxchvy0jb5no9q
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/3ahxza8suqht...
# 1      https://api.spotify.com/v1/tracks/3otlkzk1otrh...
# 2      https://api.spotify.com/v1/tracks/3zfbeiyp41hh...
# 3      https://api.spotify.com/v1/tracks/5qt4cc66g24q...
# 4      https://api.spotify.com/v1/tracks/7mh2zclofplt...
# ...                                                  ...
# 12582  https://api.spotify.com/v1/tracks/3pr0jefk308q...
# 12583  https://api.spotify.com/v1/tracks/0hskyjt75tya...
# 12584  https://api.spotify.com/v1/tracks/4yk3sromxb1c...
# 12585  https://api.spotify.com/v1/tracks/5rf4kmzzivt3...
# 12586  https://api.spotify.com/v1/tracks/5miospuqdxch...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/3ahx...      369600
# 1      https://api.spotify.com/v1/audio-analysis/3otl...      300977
# 2      https://api.spotify.com/v1/audio-analysis/3zfb...      337413
# 3      https://api.spotify.com/v1/audio-analysis/5qt4...      219147
# 4      https://api.spotify.com/v1/audio-analysis/7mh2...      160893
# ...                                                  ...         ...
# 12582  https://api.spotify.com/v1/audio-analysis/3pr0...      231037
# 12583  https://api.spotify.com/v1/audio-analysis/0hsk...      166173
# 12584  https://api.spotify.com/v1/audio-analysis/4yk3...      256157
# 12585  https://api.spotify.com/v1/audio-analysis/5rf4...      170539
# 12586  https://api.spotify.com/v1/audio-analysis/5mio...      159595
#
#       time_signature  cluster
# 0                  4        3
# 1                  4        3
# 2                  4        4
# 3                  4        5
# 4                  4        3
# ...              ...      ...
# 12582              4        3
# 12583              4        3
# 12584              4        5
# 12585              4        3
# 12586              4        3
#
# [12587 rows x 22 columns]

# %%
# saving dataframe in lower case
spotify_df = spotify_df.apply(lambda x: x.astype(str).str.lower())
spotify_df.to_csv("../data/clusters_df.csv")
